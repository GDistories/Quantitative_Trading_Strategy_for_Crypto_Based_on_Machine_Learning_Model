# %% [markdown]
# # 用来读取测试各种数据

# %%
import pandas as pd
df = pd.read_csv('../balanced_twitter_btc_small.csv',lineterminator='\n')

# %%
df
# Out:
#         user_followers  user_verified                 date  \
# 0               4680.0              0  2023-03-02 00:00:00
# 1                770.0              0  2023-03-02 00:00:00
# 2                236.0              0  2023-03-02 00:00:00
# 3              12731.0              0  2023-03-02 00:00:00
# 4                197.0              0  2023-03-02 00:00:00
# ...                ...            ...                  ...
# 126430          1633.0              0  2023-03-04 11:00:00
# 126431          7448.0              0  2023-03-04 11:00:00
# 126432           421.0              0  2023-03-04 11:00:00
# 126433           672.0              0  2023-03-04 11:00:00
# 126434            53.0              0  2023-03-04 11:00:00
#
#                                                      text  \
# 0       Which #bitcoin books should I think about read...
# 1       @ThankGodForBTC I appreciate the message, but ...
# 2       CoinDashboard v3.0 is here\nAvailable on ios a...
# ...

# %%
df = pd.read_csv('merged_df.csv',lineterminator='\n')

# %%
df['close']
# Out:
# 0      38306.68
# 1      39220.16
# 2      38789.40
# 3      46386.93
# 4      46468.40
#          ...
# 700    16952.15
# 701    16945.20
# 702    17128.62
# 703    17181.92
# 704    17441.76
# Name: close, Length: 705, dtype: float64

# %%
# DF数据可视化，加上grid
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
plt.xlabel('Time')
plt.ylabel('Price')
df['close'].plot(figsize=(16, 9))
# Out:
# <Axes: xlabel='Time', ylabel='Price'>

# %%
df['close'].plot(figsize=(16, 9))
plt.axvline(x=10000, c='r')
plt.axvline(x=20000, c='r')
plt.axvline(x=30000, c='r')
plt.axvline(x=40000, c='r')
plt.axvline(x=50000, c='r')
plt.axvline(x=60000, c='r')
plt.axvline(x=70000, c='r')
plt.axvline(x=80000, c='r')
plt.axvline(x=90000, c='r')
plt.axvline(x=100000, c='r')
plt.axvline(x=110000, c='r')
plt.axvline(x=120000, c='r')
plt.axvline(x=130000, c='r')
# 加上横纵坐标
plt.xlabel('Time')
plt.ylabel('Price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 df['close'].plot(figsize=(16, 9))
# ----> 2 plt.axvline(x=10000, c='r')
#       3 plt.axvline(x=20000, c='r')
#       4 plt.axvline(x=30000, c='r')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 模型结构可视化

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.utils import plot_model

# %%
import tensorflow.keras.models as models
from tensorflow.keras.utils import plot_model#读取模型
# 指定模型文件的路径
model_path = 'single_feature_model_2.keras'

# 加载模型

# 加载模型
loaded_model = models.load_model(model_path)

# 可视化模型结构并保存为图片
plot_model(loaded_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 9
#       4 model_path = 'single_feature_model_2.keras'
#       6 # 加载模型
#       7
#       8 # 加载模型
# ----> 9 loaded_model = models.load_model(model_path)
#      11 # 可视化模型结构并保存为图片
#      12 plot_model(loaded_model)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/saving/saving_api.py:254, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     249     if kwargs:
#     250         raise ValueError(
#     251             "The following argument(s) are not supported "
#     252             f"with the native Keras format: {list(kwargs.keys())}"
#     253         )
# --> 254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
# ...
